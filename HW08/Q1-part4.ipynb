# %% [markdown]
# ## **Problem 8: SQL**

# %% [markdown]
# # Part 4.

# %%
import json
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from huggingface_hub.utils import disable_progress_bars
import re
import os
from sentence_transformers import SentenceTransformer
import faiss 

os.environ["TORCH_COMPILE_DISABLE"] = "1" 
os.environ["HF_HUB_DOWNLOAD_TIMEOUT"] = "900" 
disable_progress_bars()

DATA_DIR = "spider" 
MODEL_ID = "google/gemma-2b-it" 
EMBEDDER_MODEL_ID = "sentence-transformers/all-MiniLM-L6-v2" 

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,                 
    bnb_4bit_use_double_quant=True,    
    bnb_4bit_quant_type="nf4",         
    bnb_4bit_compute_dtype=torch.bfloat16, 
)

try:
    tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_ID,
        quantization_config=bnb_config, 
        device_map="auto"               
    )
    model.eval() 
except Exception as e:
    print(f"Failed to load LLM: {e}")
    exit()

try:
    embedder = SentenceTransformer(EMBEDDER_MODEL_ID)
    embedder.eval() 
except Exception as e:
    print(f"Failed to load Embedder: {e}")
    exit()

def load_json_file(filepath):
    if not os.path.exists(filepath):
        raise FileNotFoundError(f"File not found: {filepath}")
    with open(filepath, 'r', encoding='utf-8') as f:
        return json.load(f)

def load_sql_file_as_list(filepath):
    if not os.path.exists(filepath):
        raise FileNotFoundError(f"File not found: {filepath}")
    with open(filepath, 'r', encoding='utf-8') as f:
        content = f.read()
        content = re.sub(r'--.*$', '', content, flags=re.MULTILINE)
        content = re.sub(r'/\*.*?\*/', '', content, flags=re.DOTALL)
        queries = [q.strip() for q in content.split(';') if q.strip()]
        return queries

def get_schema_chunks_for_db(db_id, tables_data, include_pk_fk=True):
    db_found = None
    for db in tables_data:
        if db['db_id'] == db_id:
            db_found = db
            break
    
    if not db_found:
        return [] 

    chunks = []
    for table_idx, table_name_original in enumerate(db_found['table_names_original']):
        table_schema_text = f"CREATE TABLE {table_name_original} (\n"
        table_cols = []
        for col_idx, (col_table_idx, col_name_original) in enumerate(db_found['column_names_original']):
            if col_table_idx == table_idx:
                col_type = "TEXT" 
                table_cols.append(f"   {col_name_original} {col_type}")
        
        table_schema_text += ",\n".join(table_cols)
        table_schema_text += "\n);"
        
        pk_fk_info = ""
        if include_pk_fk:
            for pk_col_idx in db_found.get('primary_keys', []):
                pk_table_idx, pk_col_name = db_found['column_names_original'][pk_col_idx]
                if db_found['table_names_original'][pk_table_idx] == table_name_original:
                    pk_fk_info += f"\n-- {table_name_original}.{pk_col_name} is PRIMARY KEY"
            
            for fk_info in db_found.get('foreign_keys', []):
                fk_col_idx = fk_info[0]
                ref_col_idx = fk_info[1]
                fk_table_idx, fk_col_name = db_found['column_names_original'][fk_col_idx]
                if db_found['table_names_original'][fk_table_idx] == table_name_original:
                    ref_table_idx, ref_col_name = db_found['column_names_original'][ref_col_idx]
                    ref_table_name = db_found['table_names_original'][ref_table_idx]
                    pk_fk_info += f"\n-- {table_name_original}.{fk_col_name} REFERENCES {ref_table_name}.{ref_col_name}"
        
        chunk_text = table_schema_text + pk_fk_info
        chunks.append({
            "text": chunk_text,
            "db_id": db_id,
            "table_name": table_name_original
        })
    return chunks

def create_sql_generation_prompt(question, retrieved_schema_chunks_text):
    prompt = (
        "You are a skilled SQL assistant. Given the following SQL database schema information and a natural language question, generate the correct SQL query.\n"
        "Do not make up table or column names. Only use the ones that exist in the provided schema information.\n\n"
        "### Relevant Database Schema Information:\n" 
        f"{retrieved_schema_chunks_text}\n\n"
        "### Question:\n"
        f"{question}\n\n"
        "### SQL Query:\n"
    )
    return prompt

def extract_sql_from_model_output(generated_text, prompt_text):
    cleaned_text = generated_text.replace(prompt_text, "").strip()
    cleaned_text = re.sub(r'```sql\s*', '', cleaned_text, flags=re.IGNORECASE)
    cleaned_text = re.sub(r'```\s*', '', cleaned_text, flags=re.IGNORECASE)
    if ';' in cleaned_text:
        cleaned_text = cleaned_text.split(';')[0].strip()
    return cleaned_text

def normalize_sql(sql_query):
    sql_query = re.sub(r'\s+', ' ', sql_query).strip()
    sql_query = sql_query.upper()
    return sql_query

def calculate_exact_match(predicted_sql, gold_sql):
    return 1 if normalize_sql(predicted_sql) == normalize_sql(gold_sql) else 0

def calculate_jaccard_similarity(predicted_sql, gold_sql):
    set1 = set(normalize_sql(predicted_sql).split())
    set2 = set(normalize_sql(gold_sql).split())
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    if union == 0:
        return 1.0 
    return intersection / union

try:
    dev_data = load_json_file(os.path.join(DATA_DIR, "dev.json"))
    print(f"Loaded {len(dev_data)} dev samples.")

    tables_data = load_json_file(os.path.join(DATA_DIR, "tables.json"))
    print(f"Loaded {len(tables_data)} table schemas.")

except FileNotFoundError as e:
    print(f"[ERROR] {e}")
    exit()

all_schema_chunks = []
for db_entry in tables_data:
    all_schema_chunks.extend(get_schema_chunks_for_db(db_entry['db_id'], tables_data, include_pk_fk=True)) # Use full schema for indexing

chunk_texts = [chunk['text'] for chunk in all_schema_chunks]
chunk_db_ids = [chunk['db_id'] for chunk in all_schema_chunks]
chunk_table_names = [chunk['table_name'] for chunk in all_schema_chunks]
chunk_embeddings = embedder.encode(chunk_texts, show_progress_bar=True, convert_to_tensor=True)

embedding_dimension = chunk_embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dimension) 
index.add(chunk_embeddings.cpu().numpy()) 

def retrieve_relevant_schema_info(question, db_id, top_k_tables=3):
    db_specific_indices = [i for i, id_val in enumerate(chunk_db_ids) if id_val == db_id]
    
    if not db_specific_indices:
        return get_schema_chunks_for_db(db_id, tables_data, include_pk_fk=True)[0]['text'] if get_schema_chunks_for_db(db_id, tables_data, include_pk_fk=True) else ""

    db_specific_embeddings = chunk_embeddings[db_specific_indices].cpu().numpy()
    db_index = faiss.IndexFlatL2(embedding_dimension)
    db_index.add(db_specific_embeddings)
    question_embedding = embedder.encode(question, convert_to_tensor=True).cpu().numpy().reshape(1, -1)
    distances, retrieved_local_indices = db_index.search(question_embedding, top_k_tables)
    retrieved_global_indices = [db_specific_indices[idx] for idx in retrieved_local_indices[0]]
    retrieved_chunks_text = [all_schema_chunks[idx]['text'] for idx in retrieved_global_indices]
    
    return "\n\n".join(retrieved_chunks_text)

exact_matches = 0
jaccard_scores = 0.0
total_processed_samples = 0

num_samples_to_test = len(dev_data) 

for i, sample in enumerate(dev_data[:num_samples_to_test]):
    question = sample['question']
    db_id = sample['db_id']
    gold_sql = sample['query'] 
    
    retrieved_schema_text = retrieve_relevant_schema_info(question, db_id, top_k_tables=3) 
    prompt = create_sql_generation_prompt(question, retrieved_schema_text)
    
    generated_sql = "" 
    try:
        input_ids = tokenizer(prompt, return_tensors="pt").to(model.device) 
        with torch.no_grad(): 
            outputs = model.generate(
                **input_ids,
                max_new_tokens=100, 
                num_beams=1,        
                do_sample=False,    
                pad_token_id=tokenizer.eos_token_id 
            )
            
        generated_text_full = tokenizer.decode(outputs[0], skip_special_tokens=True)
        generated_sql = extract_sql_from_model_output(generated_text_full, prompt)


        em = calculate_exact_match(generated_sql, gold_sql)
        js = calculate_jaccard_similarity(generated_sql, gold_sql)

        exact_matches += em
        jaccard_scores += js
        total_processed_samples += 1

        if i < 100: 
            print(f"\n--- Sample {i+1} (RAG) ---")
            print(f"Database ID: {db_id}")
            print(f"Question: {question}")
            print(f"Retrieved Schema:\n{retrieved_schema_text[:300]}...") 
            print(f"Generated SQL: {generated_sql}")
            print(f"Gold SQL: {gold_sql}")
            print(f"Exact Match (EM): {em:.4f}, Jaccard Score (JS): {js:.4f}")

    except Exception as e:
        print(f"[ERROR] Processing sample {i} (Question: {question}, DB: {db_id}): {e}")
        
print("\n Final Evaluation Results for Model with RAG:")
if total_processed_samples > 0:
    avg_em = exact_matches / total_processed_samples
    avg_js = jaccard_scores / total_processed_samples
    print(f"Total samples evaluated: {total_processed_samples}")
    print(f"Average Exact Match (EM): {avg_em:.4f}")
    print(f"Average Jaccard Similarity (JS): {avg_js:.4f}")
else:
    print("No samples were successfully evaluated.")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loaded 1034 dev samples.
# Loaded 166 table schemas.
# Batches:   0%|          | 0/28 [00:00<?, ?it/s]
# --- Sample 1 (RAG) ---
# Database ID: concert_singer
# Question: How many singers do we have?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT COUNT(*) FROM singer
# Gold SQL: SELECT count(*) FROM singer
# Exact Match (EM): 1.0000, Jaccard Score (JS): 1.0000
#
# --- Sample 2 (RAG) ---
# Database ID: concert_singer
# Question: What is the total number of singers?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT COUNT(*) FROM singer
# Gold SQL: SELECT count(*) FROM singer
# Exact Match (EM): 1.0000, Jaccard Score (JS): 1.0000
#
# --- Sample 3 (RAG) ---
# Database ID: concert_singer
# Question: Show name, country, age for all singers ordered by age from the oldest to the youngest.
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Name, s.Country, s.Age
# FROM singer s
# ORDER BY s.Age DESC
# Gold SQL: SELECT name ,  country ,  age FROM singer ORDER BY age DESC
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4286
#
# --- Sample 4 (RAG) ---
# Database ID: concert_singer
# Question: What are the names, countries, and ages for every singer in descending order of age?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Name, s.Country, s.Age
# FROM singer s
# ORDER BY s.Age DESC
# Gold SQL: SELECT name ,  country ,  age FROM singer ORDER BY age DESC
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4286
#
# --- Sample 5 (RAG) ---
# Database ID: concert_singer
# Question: What is the average, minimum, and maximum age of all singers from France?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT AVG(Age), MIN(Age), MAX(Age)
# FROM singer
# WHERE Country = 'France'
# Gold SQL: SELECT avg(age) ,  min(age) ,  max(age) FROM singer WHERE country  =  'France'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.6154
#
# --- Sample 6 (RAG) ---
# Database ID: concert_singer
# Question: What is the average, minimum, and maximum age for all French singers?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT AVG(Age), MIN(Age), MAX(Age)
# FROM singer
# WHERE Country = 'France'
# GROUP BY Country
# Gold SQL: SELECT avg(age) ,  min(age) ,  max(age) FROM singer WHERE country  =  'France'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.5333
#
# --- Sample 7 (RAG) ---
# Database ID: concert_singer
# Question: Show the name and the release year of the song by the youngest singer.
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Name, sr.Song_release_year
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE s.Age = (SELECT MIN(Age) FROM singer)
# ORDER BY s.Name ASC
# Gold SQL: SELECT song_name ,  song_release_year FROM singer ORDER BY age LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.1515
#
# --- Sample 8 (RAG) ---
# Database ID: concert_singer
# Question: What are the names and release years for all the songs of the youngest singer?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Name, sr.Song_release_year
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE s.Age = (SELECT MIN(Age) FROM singer)
# ORDER BY s.Name
# Gold SQL: SELECT song_name ,  song_release_year FROM singer ORDER BY age LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.1562
#
# --- Sample 9 (RAG) ---
# Database ID: concert_singer
# Question: What are all distinct countries where singers above age 20 are from?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT DISTINCT s.Country
# FROM singer s
# JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE s.Age > 20
# Gold SQL: SELECT DISTINCT country FROM singer WHERE age  >  20
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3043
#
# --- Sample 10 (RAG) ---
# Database ID: concert_singer
# Question: What are  the different countries with singers above age 20?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT DISTINCT s.Country
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE s.Age > 20
# Gold SQL: SELECT DISTINCT country FROM singer WHERE age  >  20
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2917
#
# --- Sample 11 (RAG) ---
# Database ID: concert_singer
# Question: Show all countries and the number of singers in each country.
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Country, COUNT(s.Singer_ID) AS num_singers
# FROM singer s
# INNER JOIN singer_in_concert sic
# ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c
# ON sic.concert_ID = c.concert_ID
# GROUP BY s.Country
# ORDER BY s.Country
# Gold SQL: SELECT country ,  count(*) FROM singer GROUP BY country
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.1852
#
# --- Sample 12 (RAG) ---
# Database ID: concert_singer
# Question: How many singers are from each country?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Singer_ID, c.Country
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# GROUP BY s.Singer_ID, c.Country
# ORDER BY s.Singer_ID
# Gold SQL: SELECT country ,  count(*) FROM singer GROUP BY country
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2083
#
# --- Sample 13 (RAG) ---
# Database ID: concert_singer
# Question: List all song names by singers above the average age.
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Name, c.Song_Name
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE s.Age > (SELECT AVG(Age) FROM singer)
# ORDER BY s.Name
# Gold SQL: SELECT song_name FROM singer WHERE age  >  (SELECT avg(age) FROM singer)
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2759
#
# --- Sample 14 (RAG) ---
# Database ID: concert_singer
# Question: What are all the song names by singers who are older than average?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Name, c.Song_Name
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE s.Age > (SELECT AVG(Age) FROM singer)
# Gold SQL: SELECT song_name FROM singer WHERE age  >  (SELECT avg(age) FROM singer)
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3077
#
# --- Sample 15 (RAG) ---
# Database ID: concert_singer
# Question: Show location and name for all stadiums with a capacity between 5000 and 10000.
# Retrieved Schema:
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#    Highest TEXT,
#    Lowest TEXT,
#    Average TEXT
# );
# -- stadium.Stadium_ID is PRIMARY KEY
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -...
# Generated SQL: SELECT s.Location, s.Name
# FROM stadium s
# WHERE s.Capacity BETWEEN 5000 AND 10000
# Gold SQL: SELECT LOCATION ,  name FROM stadium WHERE capacity BETWEEN 5000 AND 10000
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.5000
#
# --- Sample 16 (RAG) ---
# Database ID: concert_singer
# Question: What are the locations and names of all stations with capacity between 5000 and 10000?
# Retrieved Schema:
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#    Highest TEXT,
#    Lowest TEXT,
#    Average TEXT
# );
# -- stadium.Stadium_ID is PRIMARY KEY
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -...
# Generated SQL: SELECT DISTINCT s.Location, s.Name
# FROM stadium s
# INNER JOIN singer_in_concert sic
# ON s.Stadium_ID = sic.concert_ID
# INNER JOIN concert c
# ON sic.concert_ID = c.concert_ID
# WHERE s.Capacity BETWEEN 5000 AND 10000
# Gold SQL: SELECT LOCATION ,  name FROM stadium WHERE capacity BETWEEN 5000 AND 10000
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2857
#
# --- Sample 17 (RAG) ---
# Database ID: concert_singer
# Question: What is the average and the maximum capacity of all stadiums?
# Retrieved Schema:
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#    Highest TEXT,
#    Lowest TEXT,
#    Average TEXT
# );
# -- stadium.Stadium_ID is PRIMARY KEY
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -...
# Generated SQL: SELECT AVG(capacity) AS average_capacity, MAX(capacity) AS maximum_capacity
# FROM stadium
# Gold SQL: SELECT avg(capacity) ,  max(capacity) FROM stadium
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.5556
#
# --- Sample 18 (RAG) ---
# Database ID: concert_singer
# Question: What is the average and maximum capacities for all stations?
# Retrieved Schema:
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#    Highest TEXT,
#    Lowest TEXT,
#    Average TEXT
# );
# -- stadium.Stadium_ID is PRIMARY KEY
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -...
# Generated SQL: SELECT AVG(capacity) AS average_capacity, MAX(capacity) AS max_capacity
# FROM stadium
# Gold SQL: SELECT avg(capacity) ,  max(capacity) FROM stadium
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.5556
#
# --- Sample 19 (RAG) ---
# Database ID: concert_singer
# Question: What is the name and capacity for the stadium with highest average attendance?
# Retrieved Schema:
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#    Highest TEXT,
#    Lowest TEXT,
#    Average TEXT
# );
# -- stadium.Stadium_ID is PRIMARY KEY
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -...
# Generated SQL: SELECT s.Name, s.Capacity
# FROM stadium s
# WHERE s.Average = (SELECT MAX(s.Average) FROM stadium)
# ORDER BY s.Capacity DESC
# Gold SQL: SELECT name ,  capacity FROM stadium ORDER BY average DESC LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2857
#
# --- Sample 20 (RAG) ---
# Database ID: concert_singer
# Question: What is the name and capacity for the stadium with the highest average attendance?
# Retrieved Schema:
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#    Highest TEXT,
#    Lowest TEXT,
#    Average TEXT
# );
# -- stadium.Stadium_ID is PRIMARY KEY
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -...
# Generated SQL: SELECT s.Name, s.Capacity
# FROM stadium s
# WHERE s.Average = (SELECT MAX(s.Average) FROM stadium)
# ORDER BY s.Capacity DESC
# Gold SQL: SELECT name ,  capacity FROM stadium ORDER BY average DESC LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2857
#
# --- Sample 21 (RAG) ---
# Database ID: concert_singer
# Question: How many concerts are there in year 2014 or 2015?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert...
# Generated SQL: SELECT COUNT(*) FROM concert WHERE Year = 2014 OR Year = 2015
# Gold SQL: SELECT count(*) FROM concert WHERE YEAR  =  2014 OR YEAR  =  2015
# Exact Match (EM): 1.0000, Jaccard Score (JS): 1.0000
#
# --- Sample 22 (RAG) ---
# Database ID: concert_singer
# Question: How many concerts occurred in 2014 or 2015?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert...
# Generated SQL: SELECT COUNT(*) FROM concert WHERE Year = '2014' OR Year = '2015'
# Gold SQL: SELECT count(*) FROM concert WHERE YEAR  =  2014 OR YEAR  =  2015
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.6667
#
# --- Sample 23 (RAG) ---
# Database ID: concert_singer
# Question: Show the stadium name and the number of concerts in each stadium.
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT s.Name, COUNT(*) AS num_concerts
# FROM stadium s
# INNER JOIN singer_in_concert sic ON s.Stadium_ID = sic.concert_ID
# GROUP BY s.Name
# ORDER BY num_concerts DESC
# Gold SQL: SELECT T2.name ,  count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id GROUP BY T1.stadium_id
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3571
#
# --- Sample 24 (RAG) ---
# Database ID: concert_singer
# Question: For each stadium, how many concerts play there?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT COUNT(*) AS num_concerts
# FROM concert
# GROUP BY stadium_id
# Gold SQL: SELECT T2.name ,  count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id GROUP BY T1.stadium_id
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3684
#
# --- Sample 25 (RAG) ---
# Database ID: concert_singer
# Question: Show the stadium name and capacity with most number of concerts in year 2014 or after.
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT s.Name, c.Stadium_ID, COUNT(c.concert_ID) AS num_concerts
# FROM stadium s
# INNER JOIN singer_in_concert sic ON s.Stadium_ID = sic.concert_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE c.Year = 2014
# GROUP BY s.Name, c.Stadium_ID
# ORDER BY num_concerts DESC
# Gold SQL: SELECT T2.name ,  T2.capacity FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  >=  2014 GROUP BY T2.stadium_id ORDER BY count(*) DESC LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3500
#
# --- Sample 26 (RAG) ---
# Database ID: concert_singer
# Question: What is the name and capacity of the stadium  with the most concerts after 2013?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT s.Name, s.Capacity
# FROM stadium s
# INNER JOIN concert c ON s.Stadium_ID = c.Stadium_ID
# WHERE c.Year >= 2013
# GROUP BY s.Name, s.Capacity
# ORDER BY s.Capacity DESC
# LIMIT 1
# Gold SQL: SELECT T2.name ,  T2.capacity FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  >=  2014 GROUP BY T2.stadium_id ORDER BY count(*) DESC LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4286
#
# --- Sample 27 (RAG) ---
# Database ID: concert_singer
# Question: Which year has most number of concerts?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert...
# Generated SQL: SELECT YEAR(year) AS year_with_most_concerts
# FROM concert
# GROUP BY YEAR(year)
# ORDER BY COUNT(*) DESC
# LIMIT 1
# Gold SQL: SELECT YEAR FROM concert GROUP BY YEAR ORDER BY count(*) DESC LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.7143
#
# --- Sample 28 (RAG) ---
# Database ID: concert_singer
# Question: What is the year that had the most concerts?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert...
# Generated SQL: SELECT YEAR(year) AS most_year
# FROM concert
# GROUP BY year
# ORDER BY COUNT(*) DESC
# LIMIT 1
# Gold SQL: SELECT YEAR FROM concert GROUP BY YEAR ORDER BY count(*) DESC LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.7857
#
# --- Sample 29 (RAG) ---
# Database ID: concert_singer
# Question: Show the stadium names without any concert.
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT DISTINCT stadium.Stadium_ID
# FROM stadium
# WHERE concert_ID IS NULL
# Gold SQL: SELECT name FROM stadium WHERE stadium_id NOT IN (SELECT stadium_id FROM concert)
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2667
#
# --- Sample 30 (RAG) ---
# Database ID: concert_singer
# Question: What are the names of the stadiums without any concerts?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT DISTINCT s.Stadium_ID
# FROM stadium s
# WHERE s.Stadium_ID NOT IN (
#   SELECT DISTINCT c.Stadium_ID
#   FROM concert c
# )
# Gold SQL: SELECT name FROM stadium WHERE stadium_id NOT IN (SELECT stadium_id FROM concert)
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3333
#
# --- Sample 31 (RAG) ---
# Database ID: concert_singer
# Question: Show countries where a singer above age 40 and a singer below 30 are from.
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT DISTINCT s.Country
# FROM singer s
# JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE s.Age > 40 AND s.Age < 30
# Gold SQL: SELECT country FROM singer WHERE age  >  40 INTERSECT SELECT country FROM singer WHERE age  <  30
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2963
#
# --- Sample 32 (RAG) ---
# Database ID: concert_singer
# Question: Show names for all stadiums except for stadiums having a concert in year 2014.
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT DISTINCT s.Name
# FROM stadium s
# WHERE s.Stadium_ID NOT IN (
#   SELECT stadium_id
#   FROM concert c
#   WHERE c.Year = 2014
# )
# ORDER BY s.Name
# Gold SQL: SELECT name FROM stadium EXCEPT SELECT T2.name FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  =  2014
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2258
#
# --- Sample 33 (RAG) ---
# Database ID: concert_singer
# Question: What are the names of all stadiums that did not have a concert in 2014?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT DISTINCT s.Name
# FROM stadium s
# WHERE s.Stadium_ID NOT IN (
#   SELECT c.Stadium_ID
#   FROM concert c
#   WHERE c.Year = 2014
# )
#
# Gold SQL: SELECT name FROM stadium EXCEPT SELECT T2.name FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  =  2014
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2414
#
# --- Sample 34 (RAG) ---
# Database ID: concert_singer
# Question: Show the name and theme for all concerts and the number of singers in each concert.
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert...
# Generated SQL: SELECT c.concert_Name, c.Theme, COUNT(s.Singer_ID) AS num_singers
# FROM concert c
# INNER JOIN singer_in_concert sic ON c.concert_ID = sic.concert_ID
# INNER JOIN singer s ON sic.Singer_ID = s.Singer_ID
# GROUP BY c.concert_ID, c.Theme
# ORDER BY c.concert_ID
# Gold SQL: SELECT T2.concert_name ,  T2.theme ,  count(*) FROM singer_in_concert AS T1 JOIN concert AS T2 ON T1.concert_id  =  T2.concert_id GROUP BY T2.concert_id
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2941
#
# --- Sample 35 (RAG) ---
# Database ID: concert_singer
# Question: What are the names, themes, and number of singers for each and every concert?
# Retrieved Schema:
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMARY KEY
# -- singer_in_concert.Singer_ID REFERENCES singer.Singer_ID
# -- singer_in_concert.concert_ID REFERENCES concert.concert_ID
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Nam...
# Generated SQL: SELECT c.concert_Name, c.Theme, COUNT(s.Singer_ID) AS num_singers
# FROM concert c
# INNER JOIN singer s ON c.concert_ID = s.Singer_ID
# GROUP BY c.concert_ID, c.Theme
# ORDER BY c.concert_ID
# Gold SQL: SELECT T2.concert_name ,  T2.theme ,  count(*) FROM singer_in_concert AS T1 JOIN concert AS T2 ON T1.concert_id  =  T2.concert_id GROUP BY T2.concert_id
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2903
#
# --- Sample 36 (RAG) ---
# Database ID: concert_singer
# Question: List singer names and number of concerts for each singer.
# Retrieved Schema:
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMARY KEY
# -- singer_in_concert.Singer_ID REFERENCES singer.Singer_ID
# -- singer_in_concert.concert_ID REFERENCES concert.concert_ID
#
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#   ...
# Generated SQL: SELECT s.Singer_ID, COUNT(c.concert_ID) AS num_concerts
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# GROUP BY s.Singer_ID
# ORDER BY s.Name
# Gold SQL: SELECT T2.name ,  count(*) FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id GROUP BY T2.singer_id
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3226
#
# --- Sample 37 (RAG) ---
# Database ID: concert_singer
# Question: What are the names of the singers and number of concerts for each person?
# Retrieved Schema:
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMARY KEY
# -- singer_in_concert.Singer_ID REFERENCES singer.Singer_ID
# -- singer_in_concert.concert_ID REFERENCES concert.concert_ID
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Nam...
# Generated SQL: SELECT s.Name, COUNT(c.concert_ID) AS num_concerts
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# GROUP BY s.Singer_ID, s.Name
# ORDER BY s.Name
# Gold SQL: SELECT T2.name ,  count(*) FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id GROUP BY T2.singer_id
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3125
#
# --- Sample 38 (RAG) ---
# Database ID: concert_singer
# Question: List all singer names in concerts in year 2014.
# Retrieved Schema:
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMARY KEY
# -- singer_in_concert.Singer_ID REFERENCES singer.Singer_ID
# -- singer_in_concert.concert_ID REFERENCES concert.concert_ID
#
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#   ...
# Generated SQL: SELECT s.Name
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE c.Year = 2014
# Gold SQL: SELECT T2.name FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id JOIN concert AS T3 ON T1.concert_id  =  T3.concert_id WHERE T3.year  =  2014
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3333
#
# --- Sample 39 (RAG) ---
# Database ID: concert_singer
# Question: What are the names of the singers who performed in a concert in 2014?
# Retrieved Schema:
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMARY KEY
# -- singer_in_concert.Singer_ID REFERENCES singer.Singer_ID
# -- singer_in_concert.concert_ID REFERENCES concert.concert_ID
#
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Nam...
# Generated SQL: SELECT s.Name
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE c.Year = 2014
# Gold SQL: SELECT T2.name FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id JOIN concert AS T3 ON T1.concert_id  =  T3.concert_id WHERE T3.year  =  2014
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3333
#
# --- Sample 40 (RAG) ---
# Database ID: concert_singer
# Question: what is the name and nation of the singer who have a song having 'Hey' in its name?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Name, s.Country
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE s.Name LIKE '%Hey%'
# ORDER BY s.Name
# Gold SQL: SELECT name ,  country FROM singer WHERE song_name LIKE '%Hey%'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2143
#
# --- Sample 41 (RAG) ---
# Database ID: concert_singer
# Question: What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
# Retrieved Schema:
# CREATE TABLE singer (
#    Singer_ID TEXT,
#    Name TEXT,
#    Country TEXT,
#    Song_Name TEXT,
#    Song_release_year TEXT,
#    Age TEXT,
#    Is_male TEXT
# );
# -- singer.Singer_ID is PRIMARY KEY
#
# CREATE TABLE singer_in_concert (
#    concert_ID TEXT,
#    Singer_ID TEXT
# );
# -- singer_in_concert.concert_ID is PRIMA...
# Generated SQL: SELECT s.Name, s.Country
# FROM singer s
# INNER JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE c.Song_Name LIKE '%Hey%'
# GROUP BY s.Singer_ID, s.Name, s.Country
# Gold SQL: SELECT name ,  country FROM singer WHERE song_name LIKE '%Hey%'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2069
#
# --- Sample 42 (RAG) ---
# Database ID: concert_singer
# Question: Find the name and location of the stadiums which some concerts happened in the years of both 2014 and 2015.
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT s.Name, st.Location
# FROM stadium s
# INNER JOIN singer_in_concert sic
# ON s.Stadium_ID = sic.concert_ID
# INNER JOIN concert c
# ON sic.concert_ID = c.concert_ID
# WHERE c.Year IN (2014, 2015)
# GROUP BY s.Name, st.Location
# Gold SQL: SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2014 INTERSECT SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2015
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2222
#
# --- Sample 43 (RAG) ---
# Database ID: concert_singer
# Question: What are the names and locations of the stadiums that had concerts that occurred in both 2014 and 2015?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT s.Name AS Stadium_Name
# FROM stadium s
# INNER JOIN singer_in_concert sic ON s.Stadium_ID = sic.concert_ID
# INNER JOIN concert c ON sic.concert_ID = c.concert_ID
# WHERE c.Year = 2014 OR c.Year = 2015
# Gold SQL: SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2014 INTERSECT SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2015
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3438
#
# --- Sample 44 (RAG) ---
# Database ID: concert_singer
# Question: Find the number of concerts happened in the stadium with the highest capacity.
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT COUNT(*) AS num_concerts
# FROM concert
# WHERE Stadium_ID = (SELECT Stadium_ID FROM stadium WHERE Location = 'Stadium A')
# ORDER BY Capacity DESC
# LIMIT 1
# Gold SQL: SELECT count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id ORDER BY T2.Capacity DESC LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4444
#
# --- Sample 45 (RAG) ---
# Database ID: concert_singer
# Question: What are the number of concerts that occurred in the stadium with the largest capacity?
# Retrieved Schema:
# CREATE TABLE concert (
#    concert_ID TEXT,
#    concert_Name TEXT,
#    Theme TEXT,
#    Stadium_ID TEXT,
#    Year TEXT
# );
# -- concert.concert_ID is PRIMARY KEY
# -- concert.Stadium_ID REFERENCES stadium.Stadium_ID
#
# CREATE TABLE stadium (
#    Stadium_ID TEXT,
#    Location TEXT,
#    Name TEXT,
#    Capacity TEXT,
#  ...
# Generated SQL: SELECT COUNT(*) AS num_concerts
# FROM concert
# WHERE Stadium_ID = (SELECT Stadium_ID FROM stadium WHERE Location = 'Stadium A')
# ORDER BY Capacity DESC
# LIMIT 1
# Gold SQL: SELECT count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id ORDER BY T2.Capacity DESC LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4444
#
# --- Sample 46 (RAG) ---
# Database ID: pets_1
# Question: Find the number of pets whose weight is heavier than 10.
# Retrieved Schema:
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT COUNT(*) FROM Pets WHERE weight > 10
# Gold SQL: SELECT count(*) FROM pets WHERE weight  >  10
# Exact Match (EM): 1.0000, Jaccard Score (JS): 1.0000
#
# --- Sample 47 (RAG) ---
# Database ID: pets_1
# Question: How many pets have a greater weight than 10?
# Retrieved Schema:
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT COUNT(*) FROM Pets WHERE weight > 10
# Gold SQL: SELECT count(*) FROM pets WHERE weight  >  10
# Exact Match (EM): 1.0000, Jaccard Score (JS): 1.0000
#
# --- Sample 48 (RAG) ---
# Database ID: pets_1
# Question: Find the weight of the youngest dog.
# Retrieved Schema:
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT p.weight
# FROM Pets p
# INNER JOIN Has_Pet hp ON p.PetID = hp.PetID
# INNER JOIN Student s ON hp.StuID = s.StuID
# WHERE s.Age = (SELECT MIN(Age) FROM Student)
# ORDER BY p.weight DESC
# Gold SQL: SELECT weight FROM pets ORDER BY pet_age LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.1724
#
# --- Sample 49 (RAG) ---
# Database ID: pets_1
# Question: How much does the youngest dog weigh?
# Retrieved Schema:
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT p.weight
# FROM Pets p
# INNER JOIN Has_Pet hp ON p.PetID = hp.PetID
# INNER JOIN Student s ON hp.StuID = s.StuID
# WHERE s.Age = (SELECT MIN(Age) FROM Student)
# ORDER BY p.weight DESC
# Gold SQL: SELECT weight FROM pets ORDER BY pet_age LIMIT 1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.1724
#
# --- Sample 50 (RAG) ---
# Database ID: pets_1
# Question: Find the maximum weight for each type of pet. List the maximum weight and pet type.
# Retrieved Schema:
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT p.PetType, MAX(p.Weight) AS MaxWeight
# FROM Pets p
# INNER JOIN Has_Pet hp ON p.PetID = hp.PetID
# INNER JOIN Student s ON hp.StuID = s.StuID
# WHERE s.LName = 'John'
# GROUP BY p.PetType
# ORDER BY MaxWeight DESC
# Gold SQL: SELECT max(weight) ,  petType FROM pets GROUP BY petType
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.1613
#
# --- Sample 51 (RAG) ---
# Database ID: pets_1
# Question: List the maximum weight and type for each type of pet.
# Retrieved Schema:
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT p.weight, p.type
# FROM Pets p
# INNER JOIN Has_Pet hp ON p.PetID = hp.PetID
# INNER JOIN Student s ON hp.StuID = s.StuID
# WHERE p.type = 'Dog' OR p.type = 'Cat'
# ORDER BY p.weight DESC
# Gold SQL: SELECT max(weight) ,  petType FROM pets GROUP BY petType
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.1333
#
# --- Sample 52 (RAG) ---
# Database ID: pets_1
# Question: Find number of pets owned by students who are older than 20.
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT COUNT(*) FROM Has_Pet WHERE StuID IN (
#   SELECT StuID FROM Student WHERE Age > 20
# )
#
# Gold SQL: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3636
#
# --- Sample 53 (RAG) ---
# Database ID: pets_1
# Question: How many pets are owned by students that have an age greater than 20?
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT COUNT(*) FROM Has_Pet WHERE StuID IN (
#   SELECT StuID FROM Student WHERE Age > 20
# )
#
# Gold SQL: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3636
#
# --- Sample 54 (RAG) ---
# Database ID: pets_1
# Question: Find the number of dog pets that are raised by female students (with sex F).
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT COUNT(*) FROM Has_Pet WHERE PetType = 'Dog' AND PetOwnerID = (SELECT StuID FROM Student WHERE LName = 'Jane' AND Fname = 'Doe')
# Gold SQL: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND T3.pettype  =  'dog'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2903
#
# --- Sample 55 (RAG) ---
# Database ID: pets_1
# Question: How many dog pets are raised by female students?
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT COUNT(*)
# FROM Has_Pet
# WHERE PetType = 'Dog'
# AND StuID = (
#    SELECT StuID
#    FROM Student
#    WHERE LName = 'Jane'
#    AND Fname = 'Doe'
# )
# Gold SQL: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND T3.pettype  =  'dog'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2903
#
# --- Sample 56 (RAG) ---
# Database ID: pets_1
# Question: Find the number of distinct type of pets.
# Retrieved Schema:
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT DISTINCT pet_type FROM Pets
# Gold SQL: SELECT count(DISTINCT pettype) FROM pets
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4286
#
# --- Sample 57 (RAG) ---
# Database ID: pets_1
# Question: How many different types of pet are there?
# Retrieved Schema:
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT COUNT(DISTINCT PetType) AS num_pet_types
# FROM Pets
# Gold SQL: SELECT count(DISTINCT pettype) FROM pets
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.7143
#
# --- Sample 58 (RAG) ---
# Database ID: pets_1
# Question: Find the first name of students who have cat or dog pet.
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT LName FROM Student WHERE StuID IN (
#   SELECT StuID FROM Has_Pet WHERE PetType = 'Cat'
#   UNION ALL
#   SELECT StuID FROM Has_Pet WHERE PetType = 'Dog'
# )
# Gold SQL: SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' OR T3.pettype  =  'dog'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2581
#
# --- Sample 59 (RAG) ---
# Database ID: pets_1
# Question: What are the first names of every student who has a cat or dog as a pet?
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT S.LName, S.Fname
# FROM Student S
# INNER JOIN Has_Pet HP ON S.StuID = HP.StuID
# INNER JOIN Pets P ON HP.PetID = P.PetID
# WHERE P.PetType IN ('Cat', 'Dog')
# Gold SQL: SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' OR T3.pettype  =  'dog'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2432
#
# --- Sample 60 (RAG) ---
# Database ID: pets_1
# Question: Find the name of students who have both cat and dog pets.
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT S.LName, S.Fname, COUNT(P.PetID) AS num_pets
# FROM Student S
# INNER JOIN Has_Pet HP ON S.StuID = HP.StuID
# INNER JOIN Pets P ON HP.PetID = P.PetID
# WHERE P.PetType IN ('Cat', 'Dog')
# GROUP BY S.StuID, S.LName, S.Fname
# ORDER BY num_pets DESC
# Gold SQL: SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' INTERSECT SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2273
#
# --- Sample 61 (RAG) ---
# Database ID: pets_1
# Question: What are the students' first names who have both cats and dogs as pets?
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT S.LName, P.PetName
# FROM Student S
# INNER JOIN Has_Pet HP ON S.StuID = HP.StuID
# INNER JOIN Pets P ON HP.PetID = P.PetID
# WHERE P.PetType IN ('Cat', 'Dog')
# GROUP BY S.StuID, P.PetName
# HAVING COUNT(DISTINCT P.PetType) = 2
# Gold SQL: SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' INTERSECT SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2093
#
# --- Sample 62 (RAG) ---
# Database ID: pets_1
# Question: Find the major and age of students who do not have a cat pet.
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
# ...
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT s.StuID, COUNT(p.PetID) AS num_pets
# FROM Student s
# LEFT JOIN Has_Pet hp ON s.StuID = hp.StuID
# LEFT JOIN Pets p ON hp.PetID = p.PetID
# GROUP BY s.StuID
# Gold SQL: SELECT count(*) ,  T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3571
#
# --- Sample 81 (RAG) ---
# Database ID: pets_1
# Question: For students who have pets, how many pets does each student have?
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT s.StuID, COUNT(p.PetID) AS num_pets
# FROM Student s
# LEFT JOIN Has_Pet hp ON s.StuID = hp.StuID
# LEFT JOIN Pets p ON hp.PetID = p.PetID
# GROUP BY s.StuID
# Gold SQL: SELECT count(*) ,  T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3571
#
# --- Sample 82 (RAG) ---
# Database ID: pets_1
# Question: Find the first name and gender of student who have more than one pet.
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT S.LName, S.Fname
# FROM Student S
# JOIN Has_Pet HP ON S.StuID = HP.StuID
# GROUP BY S.StuID
# HAVING COUNT(DISTINCT HP.PetID) > 1
# Gold SQL: SELECT T1.fname ,  T1.sex FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid HAVING count(*)  >  1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4138
#
# --- Sample 83 (RAG) ---
# Database ID: pets_1
# Question: What is the first name and gender of the all the students who have more than one pet?
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT S.LName, S.Fname
# FROM Student S
# JOIN Has_Pet HP ON S.StuID = HP.StuID
# GROUP BY S.StuID
# HAVING COUNT(DISTINCT HP.PetID) > 1
# Gold SQL: SELECT T1.fname ,  T1.sex FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid HAVING count(*)  >  1
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4138
#
# --- Sample 84 (RAG) ---
# Database ID: pets_1
# Question: Find the last name of the student who has a cat that is age 3.
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName TEXT,
#    Fname TEXT,
#    Age TEXT,
#    Sex TEXT,
#    Major TEXT,
#    Advisor TEXT,
#    city_code TEXT
# );
# -- Student.StuID...
# Generated SQL: SELECT LName FROM Student WHERE StuID = (SELECT StuID FROM Student WHERE Sex = 'Female' AND PetID = (SELECT PetID FROM Pets WHERE PetType = 'Cat' AND pet_age = 3))
# Gold SQL: SELECT T1.lname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pet_age  =  3 AND T3.pettype  =  'cat'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2500
#
# --- Sample 85 (RAG) ---
# Database ID: pets_1
# Question: What is the last name of the student who has a cat that is 3 years old?
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT LName FROM Student WHERE StuID = (SELECT StuID FROM Has_Pet WHERE PetID = 'Cat')
# Gold SQL: SELECT T1.lname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pet_age  =  3 AND T3.pettype  =  'cat'
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2143
#
# --- Sample 86 (RAG) ---
# Database ID: pets_1
# Question: Find the average age of students who do not have any pet.
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT AVG(age) AS avg_age
# FROM Student
# WHERE StuID NOT IN (
#    SELECT StuID
#    FROM Has_Pet
#    WHERE PetID IS NULL
# )
# Gold SQL: SELECT avg(age) FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid)
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4167
#
# --- Sample 87 (RAG) ---
# Database ID: pets_1
# Question: What is the average age for all students who do not own any pets?
# Retrieved Schema:
# CREATE TABLE Has_Pet (
#    StuID TEXT,
#    PetID TEXT
# );
# -- Has_Pet.StuID REFERENCES Student.StuID
# -- Has_Pet.PetID REFERENCES Pets.PetID
#
# CREATE TABLE Pets (
#    PetID TEXT,
#    PetType TEXT,
#    pet_age TEXT,
#    weight TEXT
# );
# -- Pets.PetID is PRIMARY KEY
#
# CREATE TABLE Student (
#    StuID TEXT,
#    LName...
# Generated SQL: SELECT AVG(age) AS avg_age
# FROM Student
# WHERE StuID NOT IN (
#   SELECT StuID
#   FROM Has_Pet
#   WHERE PetID IS NULL
# )
# Gold SQL: SELECT avg(age) FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid)
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4167
#
# --- Sample 88 (RAG) ---
# Database ID: car_1
# Question: How many continents are there?
# Retrieved Schema:
# CREATE TABLE continents (
#    ContId TEXT,
#    Continent TEXT
# );
# -- continents.ContId is PRIMARY KEY
#
# CREATE TABLE countries (
#    CountryId TEXT,
#    CountryName TEXT,
#    Continent TEXT
# );
# -- countries.CountryId is PRIMARY KEY
# -- countries.Continent REFERENCES continents.ContId
#
# CREATE TABLE car_makers...
# Generated SQL: SELECT COUNT(*) FROM continents
# Gold SQL: SELECT count(*) FROM CONTINENTS;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.6000
#
# --- Sample 89 (RAG) ---
# Database ID: car_1
# Question: What is the number of continents?
# Retrieved Schema:
# CREATE TABLE continents (
#    ContId TEXT,
#    Continent TEXT
# );
# -- continents.ContId is PRIMARY KEY
#
# CREATE TABLE countries (
#    CountryId TEXT,
#    CountryName TEXT,
#    Continent TEXT
# );
# -- countries.CountryId is PRIMARY KEY
# -- countries.Continent REFERENCES continents.ContId
#
# CREATE TABLE car_makers...
# Generated SQL: SELECT COUNT(*) FROM continents
# Gold SQL: SELECT count(*) FROM CONTINENTS;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.6000
#
# --- Sample 90 (RAG) ---
# Database ID: car_1
# Question: How many countries does each continent have? List the continent id, continent name and the number of countries.
# Retrieved Schema:
# CREATE TABLE countries (
#    CountryId TEXT,
#    CountryName TEXT,
#    Continent TEXT
# );
# -- countries.CountryId is PRIMARY KEY
# -- countries.Continent REFERENCES continents.ContId
#
# CREATE TABLE continents (
#    ContId TEXT,
#    Continent TEXT
# );
# -- continents.ContId is PRIMARY KEY
#
# CREATE TABLE car_makers...
# Generated SQL: SELECT c.ContId, c.Continent, COUNT(*) AS CountryCount
# FROM countries c
# INNER JOIN car_makers cm ON c.CountryId = cm.CountryId
# GROUP BY c.ContId, c.Continent
# ORDER BY c.Continent
# Gold SQL: SELECT T1.ContId ,  T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.Continent GROUP BY T1.ContId;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3448
#
# --- Sample 91 (RAG) ---
# Database ID: car_1
# Question: For each continent, list its id, name, and how many countries it has?
# Retrieved Schema:
# CREATE TABLE countries (
#    CountryId TEXT,
#    CountryName TEXT,
#    Continent TEXT
# );
# -- countries.CountryId is PRIMARY KEY
# -- countries.Continent REFERENCES continents.ContId
#
# CREATE TABLE continents (
#    ContId TEXT,
#    Continent TEXT
# );
# -- continents.ContId is PRIMARY KEY
#
# CREATE TABLE car_makers...
# Generated SQL: SELECT c.ContId, c.Continent, COUNT(c.CountryId) AS CountryCount
# FROM continents c
# GROUP BY c.ContId, c.Continent
# Gold SQL: SELECT T1.ContId ,  T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.Continent GROUP BY T1.ContId;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2500
#
# --- Sample 92 (RAG) ---
# Database ID: car_1
# Question: How many countries are listed?
# Retrieved Schema:
# CREATE TABLE countries (
#    CountryId TEXT,
#    CountryName TEXT,
#    Continent TEXT
# );
# -- countries.CountryId is PRIMARY KEY
# -- countries.Continent REFERENCES continents.ContId
#
# CREATE TABLE continents (
#    ContId TEXT,
#    Continent TEXT
# );
# -- continents.ContId is PRIMARY KEY
#
# CREATE TABLE car_makers...
# Generated SQL: SELECT COUNT(*) FROM countries
# Gold SQL: SELECT count(*) FROM COUNTRIES;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.6000
#
# --- Sample 93 (RAG) ---
# Database ID: car_1
# Question: How many countries exist?
# Retrieved Schema:
# CREATE TABLE countries (
#    CountryId TEXT,
#    CountryName TEXT,
#    Continent TEXT
# );
# -- countries.CountryId is PRIMARY KEY
# -- countries.Continent REFERENCES continents.ContId
#
# CREATE TABLE continents (
#    ContId TEXT,
#    Continent TEXT
# );
# -- continents.ContId is PRIMARY KEY
#
# CREATE TABLE car_makers...
# Generated SQL: SELECT COUNT(*) FROM countries
# Gold SQL: SELECT count(*) FROM COUNTRIES;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.6000
#
# --- Sample 94 (RAG) ---
# Database ID: car_1
# Question: How many models does each car maker produce? List maker full name, id and the number.
# Retrieved Schema:
# CREATE TABLE model_list (
#    ModelId TEXT,
#    Maker TEXT,
#    Model TEXT
# );
# -- model_list.ModelId is PRIMARY KEY
# -- model_list.Maker REFERENCES car_makers.Id
#
# CREATE TABLE car_names (
#    MakeId TEXT,
#    Model TEXT,
#    Make TEXT
# );
# -- car_names.MakeId is PRIMARY KEY
# -- car_names.Model REFERENCES model...
# Generated SQL: SELECT c.Maker, c.Id, COUNT(m.ModelId) AS ModelCount
# FROM car_names c
# INNER JOIN model_list m ON c.MakeId = m.ModelId
# GROUP BY c.Maker, c.Id
# ORDER BY c.Maker, c.Id
# Gold SQL: SELECT T1.FullName ,  T1.Id ,  count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3000
#
# --- Sample 95 (RAG) ---
# Database ID: car_1
# Question: What is the full name of each car maker, along with its id and how many models it produces?
# Retrieved Schema:
# CREATE TABLE model_list (
#    ModelId TEXT,
#    Maker TEXT,
#    Model TEXT
# );
# -- model_list.ModelId is PRIMARY KEY
# -- model_list.Maker REFERENCES car_makers.Id
#
# CREATE TABLE car_names (
#    MakeId TEXT,
#    Model TEXT,
#    Make TEXT
# );
# -- car_names.MakeId is PRIMARY KEY
# -- car_names.Model REFERENCES model...
# Generated SQL: SELECT car_makers.Maker, car_makers.Id, COUNT(DISTINCT model_list.ModelId) AS Models
# FROM car_makers
# INNER JOIN model_list ON car_makers.Id = model_list.ModelId
# GROUP BY car_makers.Maker, car_makers.Id
# ORDER BY car_makers.Maker
# Gold SQL: SELECT T1.FullName ,  T1.Id ,  count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3571
#
# --- Sample 96 (RAG) ---
# Database ID: car_1
# Question: Which model of the car has the minimum horsepower?
# Retrieved Schema:
# CREATE TABLE car_names (
#    MakeId TEXT,
#    Model TEXT,
#    Make TEXT
# );
# -- car_names.MakeId is PRIMARY KEY
# -- car_names.Model REFERENCES model_list.Model
#
# CREATE TABLE model_list (
#    ModelId TEXT,
#    Maker TEXT,
#    Model TEXT
# );
# -- model_list.ModelId is PRIMARY KEY
# -- model_list.Maker REFERENCES ca...
# Generated SQL: SELECT m.ModelId
# FROM model_list m
# JOIN cars_data c ON m.ModelId = c.ModelId
# WHERE c.Horsepower = (SELECT MIN(Horsepower) FROM cars_data)
# Gold SQL: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.horsepower ASC LIMIT 1;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2069
#
# --- Sample 97 (RAG) ---
# Database ID: car_1
# Question: What is the model of the car with the smallest amount of horsepower?
# Retrieved Schema:
# CREATE TABLE car_names (
#    MakeId TEXT,
#    Model TEXT,
#    Make TEXT
# );
# -- car_names.MakeId is PRIMARY KEY
# -- car_names.Model REFERENCES model_list.Model
#
# CREATE TABLE cars_data (
#    Id TEXT,
#    MPG TEXT,
#    Cylinders TEXT,
#    Edispl TEXT,
#    Horsepower TEXT,
#    Weight TEXT,
#    Accelerate TEXT,
#    Y...
# Generated SQL: SELECT m.Model
# FROM model_list m
# INNER JOIN cars_data c ON m.ModelId = c.ModelId
# ORDER BY c.Horsepower DESC
# LIMIT 1
# Gold SQL: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.horsepower ASC LIMIT 1;
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3103
#
# --- Sample 98 (RAG) ---
# Database ID: car_1
# Question: Find the model of the car whose weight is below the average weight.
# Retrieved Schema:
# CREATE TABLE cars_data (
#    Id TEXT,
#    MPG TEXT,
#    Cylinders TEXT,
#    Edispl TEXT,
#    Horsepower TEXT,
#    Weight TEXT,
#    Accelerate TEXT,
#    Year TEXT
# );
# -- cars_data.Id is PRIMARY KEY
# -- cars_data.Id REFERENCES car_names.MakeId
#
# CREATE TABLE car_names (
#    MakeId TEXT,
#    Model TEXT,
#    Make TEX...
# Generated SQL: SELECT m.Model
# FROM car_names c
# INNER JOIN model_list lm ON c.MakeId = lm.ModelId
# INNER JOIN cars_data d ON lm.ModelId = d.ModelId
# WHERE c.Weight < (SELECT AVG(Weight) FROM cars_data)
# Gold SQL: SELECT T1.model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Weight  <  (SELECT avg(Weight) FROM CARS_DATA)
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.4138
#
# --- Sample 99 (RAG) ---
# Database ID: car_1
# Question: What is the model for the car with a weight smaller than the average?
# Retrieved Schema:
# CREATE TABLE cars_data (
#    Id TEXT,
#    MPG TEXT,
#    Cylinders TEXT,
#    Edispl TEXT,
#    Horsepower TEXT,
#    Weight TEXT,
#    Accelerate TEXT,
#    Year TEXT
# );
# -- cars_data.Id is PRIMARY KEY
# -- cars_data.Id REFERENCES car_names.MakeId
#
# CREATE TABLE car_names (
#    MakeId TEXT,
#    Model TEXT,
#    Make TEX...
# Generated SQL: SELECT m.Model
# FROM car_names c
# INNER JOIN model_list lm ON c.MakeId = lm.ModelId
# INNER JOIN cars_data d ON lm.ModelId = d.ModelId
# WHERE c.Weight < (SELECT AVG(Weight) FROM cars_data)
# ORDER BY m.Model ASC
# Gold SQL: SELECT T1.model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Weight  <  (SELECT avg(Weight) FROM CARS_DATA)
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.3750
#
# --- Sample 100 (RAG) ---
# Database ID: car_1
# Question: Find the name of the makers that produced some cars in the year of 1970?
# Retrieved Schema:
# CREATE TABLE car_names (
#    MakeId TEXT,
#    Model TEXT,
#    Make TEXT
# );
# -- car_names.MakeId is PRIMARY KEY
# -- car_names.Model REFERENCES model_list.Model
#
# CREATE TABLE car_makers (
#    Id TEXT,
#    Maker TEXT,
#    FullName TEXT,
#    Country TEXT
# );
# -- car_makers.Id is PRIMARY KEY
# -- car_makers.Country R...
# Generated SQL: SELECT car_makers.Maker
# FROM car_makers
# INNER JOIN model_list ON car_makers.Id = model_list.ModelId
# INNER JOIN car_names ON car_names.MakeId = model_list.ModelId
# WHERE car_names.Model = 'Ford' AND car_names.Year = 1970
# Gold SQL: SELECT DISTINCT T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker JOIN CAR_NAMES AS T3 ON T2.model  =  T3.model JOIN CARS_DATA AS T4 ON T3.MakeId  =  T4.id WHERE T4.year  =  '1970';
# Exact Match (EM): 0.0000, Jaccard Score (JS): 0.2571
#
#  Final Evaluation Results for Model with RAG:
# Total samples evaluated: 1034
# Average Exact Match (EM): 0.0513
# Average Jaccard Similarity (JS): 0.3995
